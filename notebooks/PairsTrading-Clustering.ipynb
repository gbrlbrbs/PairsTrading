# %% [markdown]
# # Clustering ETFs
#
# This notebook contains the required code to perform the pairs selection stage. First, it implements the three following search techniques:
#
# - No clustering
# - Clustering by category
# - Clustering with OPTICS
#
# In addittion, it considers the proposed pairs selection rules to apply on top.

# %% [markdown]
# ## Dependencies
#
# This notebook requires code from:
#
# - `class_SeriesAnalyser.py` - contains a set of functions to deal with time series analysis.
# - `class_Trader.py` - contains a set of functions concerning trading strategies.
# - `class_DataProcessor.py` - contains a set of functions concerning the data pre processing.

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
np.random.seed(1) # NumPy
import random
random.seed(3) # Python
import tensorflow as tf
tf.random.set_seed(2) # Tensorflow

# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.manifold import TSNE

# %% [markdown]
# ### Import Classes

# %%
import sys
from pathlib import Path

parent_path = str(Path.cwd().parent)

if parent_path not in sys.path:
    sys.path.append(parent_path)

from classes import class_SeriesAnalyser, class_Trader, class_DataProcessor

# %%
series_analyser = class_SeriesAnalyser.SeriesAnalyser()
trader = class_Trader.Trader()
data_processor = class_DataProcessor.DataProcessor()

# %% [markdown]
# ### Data path

# %%
data_path = Path.cwd().parent / "data"

# %% [markdown]
# # Commodity ETFs Dataset

# %% [markdown]
# We start by retrieving the data from a Dataframe saved in a pickle file, as it was previously processed in the `PairsTrading_CommodityETFS_Datapreprocessing.ipynb` notebook.

# %%
# intraday
#df_prices = pd.read_pickle('data/etfs/pickle/commodity_ETFs_intraday_interpolated_screened_no_outliers.pickle')
#df_prices = pd.read_pickle('data/etfs/pickle/commodity_ETFs_interpolated_screened.pickle')
df_prices = pd.read_pickle(data_path / 'etfs/pickle/commodity_ETFs_from_2014_complete.pickle')
subsample = 2500
min_half_life = 78 # number of points in a day
max_half_life = 20000 #~number of points in a year: 78*252
file_extension = 'intraday'

# %%
len(df_prices.columns)
# Out:
# 116

# %%
# split data in training and test
df_prices_train, df_prices_test = data_processor.split_data(
    df_prices,
    ('01-01-2013', '31-12-2015'),
    ('01-01-2016', '31-12-2016'),
    remove_nan=True
)
train_val_split = '01-01-2017'
# Out:
# Total of 116 tickers
# Total of 105 tickers after removing tickers with Nan values

# %%
len(df_prices_train) + len(df_prices_test)
# Out:
# 78222

# %% [markdown]
# # 1. No Clustering

# %%
# no_cluster_series = pd.Series(0, index=df_prices_train.columns)
# pairs_all_a_all, unique_tickers = series_analyser.get_candidate_pairs(
#     clustered_series=no_cluster_series,
#     pricing_df_train=df_prices_train,
#     pricing_df_test=df_prices_test,
#     min_half_life=min_half_life,
#     max_half_life=max_half_life,
#     min_zero_crosings=12,
#     p_value_threshold=0.01,
#     hurst_threshold=0.5,
#     subsample=subsample,
# )

# %%
print('Out of {} possible combinations'.format(len(df_prices_train.columns)*(len(df_prices_train.columns)-1)/2))
#with open('data/etfs/pickle/2014-2018/pairs_no_clustering_'+file_extension+'_only_coint.pickle', 'wb') as f:
#    pickle.dump(pairs_all_a_all, f)
# Out:
# Out of 5460.0 possible combinations

# %% [markdown]
# # 2. Clustering by Category

# %%
segment_mapper = {
    'Commodities: Agriculture':'Agriculture',
    'Commodities: Agriculture Cocoa':'Agriculture',
    'Commodities: Agriculture Coffee':'Agriculture',
    'Commodities: Agriculture Corn':'Agriculture',
    'Commodities: Agriculture Cotton':'Agriculture',
    'Commodities: Agriculture Grains':'Agriculture',
    'Commodities: Agriculture Livestock':'Agriculture',
    'Commodities: Agriculture Softs':'Agriculture',
    'Commodities: Agriculture Soybeans':'Agriculture',
    'Commodities: Agriculture Sugar':'Agriculture',
    'Commodities: Agriculture Wheat':'Agriculture',
    'Equity: Global Water':'Agriculture',
    'Commodities: Broad Market':'Broad Market',
    'Commodities: Broad Market Metals':'Broad Market',
    'Commodities: Energy':'Energy',
    'Commodities: Energy Crude Oil':'Energy',
    'Commodities: Energy Gasoline':'Energy',
    'Commodities: Energy Natural Gas':'Energy',
    'Inverse Commodities: Energy Crude Oil':'Energy',
    'Inverse Commodities: Energy Natural Gas':'Energy',
    'Leveraged Commodities: Energy Crude Oil':'Energy',
    'Leveraged Commodities: Energy Natural Gas':'Energy',
    'Equity: U.S. MLPs':'Energy',
    'Equity: U.S. Energy':'Energy',
    'Inverse Equity: U.S. Energy':'Energy',
    'Inverse Equity: U.S. Natural Gas':'Energy',
    'Equity: U.S. Oil & Gas Exploration & Production':'Energy',
    'Equity: U.S. Oil & Gas Equipment & Services':'Energy',
    'Equity: Global Oil & Gas Exploration & Production':'Energy',
    'Equity: Global Energy':'Energy',
    'Equity: Global Nuclear Energy':'Energy',
    'Equity: Global Oil & Gas Equipment & Services':'Energy',
    'Equity: Global Oil & Gas':'Energy',
    'Equity: U.S. Natural Gas':'Energy',
    'Equity: Global Coal':'Energy',
    'Leveraged Equity: U.S. Energy':'Energy',
    'Leveraged Equity: U.S. Natural Gas':'Energy',
    'Equity: China Energy':'Energy',
    'Leveraged Equity: U.S. Natural Gas':'Energy',
    'Commodities: Industrial Metals':'Industrial Metals',
    'Commodities: Industrial Metals Aluminum':'Industrial Metals',
    'Commodities: Industrial Metals Copper':'Industrial Metals',
    'Commodities: Industrial Metals Lead':'Industrial Metals',
    'Commodities: Industrial Metals Nickel':'Industrial Metals',
    'Commodities: Industrial Metals Tin':'Industrial Metals',
    'Equity: U.S. Metals & Mining':'Industrial Metals',
    'Equity: Global Metals & Mining':'Industrial Metals',
    'Commodities: Precious Metals':'Precious Metals',
    'Commodities: Precious Metals Gold':'Precious Metals',
    'Commodities: Precious Metals Palladium':'Precious Metals',
    'Commodities: Precious Metals Platinum':'Precious Metals',
    'Commodities: Precious Metals Silver':'Precious Metals',
    'Inverse Commodities: Precious Metals Gold':'Precious Metals',
    'Inverse Commodities: Precious Metals Silver':'Precious Metals',
    'Leveraged Commodities: Precious Metals Gold': 'Precious Metals',
    'Leveraged Commodities: Precious Metals Silver':'Precious Metals',
    'Leveraged Equity: Global Gold Miners':'Precious Metals',
    'Equity: Global Gold Miners':'Precious Metals',
    'Equity: Global Silver Miners':'Precious Metals',
    'Inverse Equity: Global Gold Miners':'Precious Metals'
}

clustering_mapper = {
    'Agriculture':0,
    'Energy':1,
    'Industrial Metals':2,
    'Precious Metals':3,
    'Broad Market': 4
}

# %%
ticker_path = data_path / "etfs/pickle/ticker_segment_dict.pickle"
with open(ticker_path, 'rb') as handle:
    ticker_segment_dict = pickle.load(handle)

df_category = pd.DataFrame(data=df_prices_train.columns, columns=['Ticker'])
df_category['Segment'] = df_category['Ticker'].apply(lambda row: ticker_segment_dict[row])
df_category['Category'] = df_category['Segment'].apply(lambda row: segment_mapper[row])
df_category['Category_cluster'] = df_category['Category'].apply(lambda row: clustering_mapper[row])
df_category = df_category.set_index('Ticker')

ticker_category_dict = pd.Series(df_category['Category'].values, index=df_category.index).to_dict()
with open(data_path / 'etfs/pickle/ticker_category_dict.pickle', 'wb') as handle:
    pickle.dump(ticker_category_dict, handle)

# %%
print('Trading days: ', len(np.unique(df_prices_train.index.date))+len(np.unique(df_prices_test.index.date)))
print('Begin: ', df_prices_train.index.date[0])
print('End: ', df_prices_test.index.date[-1])
print('Samples: {}: {}-{}-{} '.format(len(df_prices_train+df_prices_test), len(df_prices_train[:train_val_split]),
                                      len(df_prices_train[train_val_split:]), len(df_prices_test)))
print(df_category['Category'].value_counts())
combinations = 0
for i,count in enumerate(df_category['Category'].value_counts().values):
    combinations += count*(count-1)
print('Possible number of pairs: ', combinations)
# Out:
# Trading days:  1007
# Begin:  2013-01-02
# End:  2016-12-30
# Samples: 78222: 58602-0-19620
# Energy               48
# Precious Metals      29
# Agriculture          11
# Broad Market         11
# Industrial Metals     6
# Name: Category, dtype: int64
# Possible number of pairs:  3318

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df_category.drop(['Category_cluster'], axis=1))
# Out:
#                                                 Segment           Category
# Ticker
# AGQ       Leveraged Commodities: Precious Metals Silver    Precious Metals
# CGW                                Equity: Global Water        Agriculture
# DBA                            Commodities: Agriculture        Agriculture
# DBB                      Commodities: Industrial Metals  Industrial Metals
# DBC                           Commodities: Broad Market       Broad Market
# DBE                                 Commodities: Energy             Energy
# DBO                       Commodities: Energy Crude Oil             Energy
# DBP                        Commodities: Precious Metals    Precious Metals
# DBS                 Commodities: Precious Metals Silver    Precious Metals
# DGL                   Commodities: Precious Metals Gold    Precious Metals
# DGP         Leveraged Commodities: Precious Metals Gold    Precious Metals
# DGZ           Inverse Commodities: Precious Metals Gold    Precious Metals
# DIG                       Leveraged Equity: U.S. Energy             Energy
# DJP                           Commodities: Broad Market       Broad Market
# DTO               Inverse Commodities: Energy Crude Oil             Energy
# DUG                         Inverse Equity: U.S. Energy             Energy
# DZZ           Inverse Commodities: Precious Metals Gold    Precious Metals
# ERX                       Leveraged Equity: U.S. Energy             Energy
# ERY                         Inverse Equity: U.S. Energy             Energy
# FCG                            Equity: U.S. Natural Gas             Energy
# FIW                                Equity: Global Water        Agriculture
# FXN                                 Equity: U.S. Energy             Energy
# GCC                           Commodities: Broad Market       Broad Market
# GDX                          Equity: Global Gold Miners    Precious Metals
# GLD                   Commodities: Precious Metals Gold    Precious Metals
# GLL           Inverse Commodities: Precious Metals Gold    Precious Metals
# GSG                           Commodities: Broad Market       Broad Market
# GSP                           Commodities: Broad Market       Broad Market
# IAU                   Commodities: Precious Metals Gold    Precious Metals
# IEO     Equity: U.S. Oil & Gas Exploration & Production             Energy
# IEZ         Equity: U.S. Oil & Gas Equipment & Services             Energy
# IXC                               Equity: Global Energy             Energy
# IYE                                 Equity: U.S. Energy             Energy
# KOL                                 Equity: Global Coal             Energy
# NIB                      Commodities: Agriculture Cocoa        Agriculture
# NLR                       Equity: Global Nuclear Energy             Energy
# OIH       Equity: Global Oil & Gas Equipment & Services             Energy
# PHO                                Equity: Global Water        Agriculture
# PIO                                Equity: Global Water        Agriculture
# PXE     Equity: U.S. Oil & Gas Exploration & Production             Energy
# PXI                                 Equity: U.S. Energy             Energy
# PXJ         Equity: U.S. Oil & Gas Equipment & Services             Energy
# RJA                            Commodities: Agriculture        Agriculture
# RJI                           Commodities: Broad Market       Broad Market
# RJZ                    Commodities: Broad Market Metals       Broad Market
# RYE                                 Equity: U.S. Energy             Energy
# SCO               Inverse Commodities: Energy Crude Oil             Energy
# SLV                 Commodities: Precious Metals Silver    Precious Metals
# UCO             Leveraged Commodities: Energy Crude Oil             Energy
# UGA                        Commodities: Energy Gasoline             Energy
# UGL         Leveraged Commodities: Precious Metals Gold    Precious Metals
# UNG                     Commodities: Energy Natural Gas             Energy
# USL                       Commodities: Energy Crude Oil             Energy
# USO                       Commodities: Energy Crude Oil             Energy
# VDE                                 Equity: U.S. Energy             Energy
# XES         Equity: U.S. Oil & Gas Equipment & Services             Energy
# XLE                                 Equity: U.S. Energy             Energy
# XME                        Equity: U.S. Metals & Mining  Industrial Metals
# XOP     Equity: U.S. Oil & Gas Exploration & Production             Energy
# AMJ                                   Equity: U.S. MLPs             Energy
# AMLP                                  Equity: U.S. MLPs             Energy
# AMU                                   Equity: U.S. MLPs             Energy
# BCM                           Commodities: Broad Market       Broad Market
# BNO                       Commodities: Energy Crude Oil             Energy
# BOIL          Leveraged Commodities: Energy Natural Gas             Energy
# CANE                     Commodities: Agriculture Sugar        Agriculture
# COPX                     Equity: Global Metals & Mining  Industrial Metals
# CORN                      Commodities: Agriculture Corn        Agriculture
# DGLD          Inverse Commodities: Precious Metals Gold    Precious Metals
# DJCI                          Commodities: Broad Market       Broad Market
# DSLV        Inverse Commodities: Precious Metals Silver    Precious Metals
# DUST                 Inverse Equity: Global Gold Miners    Precious Metals
# EMLP                                  Equity: U.S. MLPs             Energy
# FRAK                           Equity: Global Oil & Gas             Energy
# GASL                 Leveraged Equity: U.S. Natural Gas             Energy
# GDXJ                         Equity: Global Gold Miners    Precious Metals
# GLTR                       Commodities: Precious Metals    Precious Metals
# GOEX                         Equity: Global Gold Miners    Precious Metals
# KOLD            Inverse Commodities: Energy Natural Gas             Energy
# LIT                      Equity: Global Metals & Mining  Industrial Metals
# MLPA                                  Equity: U.S. MLPs             Energy
# MLPG                                  Equity: U.S. MLPs             Energy
# MLPI                                  Equity: U.S. MLPs             Energy
# MLPY                                  Equity: U.S. MLPs             Energy
# NUGT               Leveraged Equity: Global Gold Miners    Precious Metals
# PALL             Commodities: Precious Metals Palladium    Precious Metals
# PICK                     Equity: Global Metals & Mining  Industrial Metals
# PPLT              Commodities: Precious Metals Platinum    Precious Metals
# PSCE                                Equity: U.S. Energy             Energy
# REMX                     Equity: Global Metals & Mining  Industrial Metals
# RING                         Equity: Global Gold Miners    Precious Metals
# SGOL                  Commodities: Precious Metals Gold    Precious Metals
# SIL                        Equity: Global Silver Miners    Precious Metals
# SILJ                       Equity: Global Silver Miners    Precious Metals
# SIVR                Commodities: Precious Metals Silver    Precious Metals
# SLVP                       Equity: Global Silver Miners    Precious Metals
# SOYB                  Commodities: Agriculture Soybeans        Agriculture
# UCI                           Commodities: Broad Market       Broad Market
# UGAZ          Leveraged Commodities: Energy Natural Gas             Energy
# UNL                     Commodities: Energy Natural Gas             Energy
# URA                       Equity: Global Nuclear Energy             Energy
# USCI                          Commodities: Broad Market       Broad Market
# WEAT                     Commodities: Agriculture Wheat        Agriculture
# YMLP                                  Equity: U.S. MLPs             Energy
# ZSL         Inverse Commodities: Precious Metals Silver    Precious Metals

# %%
pairs_category, unique_tickers = series_analyser.get_candidate_pairs(
    clustered_series=df_category['Category_cluster'],
    pricing_df_train=df_prices_train,
    pricing_df_test=df_prices_test,
    min_half_life=min_half_life,
    max_half_life=max_half_life,
    min_zero_crosings=12,
    p_value_threshold=0.01,
    hurst_threshold=0.5,
    subsample=subsample,
)

pairs_found_category = len(pairs_category)
#with open('data/etfs/pickle/2012-2016/pairs_category_'+file_extension+'.pickle', 'wb') as f:
#    pickle.dump(pairs_category, f)
# Out:
# Cluster 1/5
# Cluster 2/5
# Cluster 3/5
# Cluster 4/5
# Cluster 5/5
# Found 51 pairs
# The pairs contain 40 unique tickers
# Pairs Selection failed stage:  {'cointegration': 1598, 'hurst_exponent': 1, 'half_life': 9, 'None': 51}

# %%
categories_found = pd.Series([ticker_category_dict[pair[0]] for pair in pairs_category])
categories_found.value_counts()
# Out:
# Energy             40
# Precious Metals    11
# dtype: int64

# %% [markdown]
# # 3. Clustering using Usupervised Learning

# %% [markdown]
# ## PCA on returns

# %% [markdown]
# **Obtain returns**

# %%
df_returns = data_processor.get_return_series(df_prices_train)
df_returns.head()
# Out:
#                           AGQ       CGW       DBA       DBB       DBC  \
# Date
# 2013-01-02 14:40:00  0.001722  0.004083  0.000000 -0.000514 -0.000721
# 2013-01-02 14:45:00 -0.003183  0.000245 -0.000358  0.000103 -0.000722
# 2013-01-02 14:50:00 -0.003193  0.000000  0.000358 -0.000103 -0.000325
# 2013-01-02 14:55:00  0.004271  0.000000  0.000322  0.002008  0.001409
# 2013-01-02 15:00:00  0.003827  0.000000  0.000393 -0.000514  0.000722
#
#                           DBE       DBO       DBP       DBS       DGL  ...  \
# Date                                                                   ...
# 2013-01-02 14:40:00 -0.009513 -0.000770  0.000351  0.000545  0.000685  ...
# 2013-01-02 14:45:00  0.000722 -0.000732  0.000175 -0.002029  0.000000  ...
# 2013-01-02 14:50:00  0.000108  0.000000  0.000053  0.000000  0.000000  ...
# 2013-01-02 14:55:00 -0.000830  0.001889  0.000631 -0.001845  0.000860  ...
# 2013-01-02 15:00:00  0.001083  0.000770  0.000351  0.004451  0.002421  ...
#
#                          SLVP  SOYB  UCI      UGAZ       UNL       URA  \
# Date
# 2013-01-02 14:40:00 -0.005767   0.0  0.0 -0.002564 -0.000595  0.002952
# 2013-01-02 14:45:00  0.000000   0.0  0.0  0.000000 -0.002382 -0.004415
# 2013-01-02 14:50:00  0.003558   0.0  0.0  0.001542  0.000000 -0.001333
# 2013-01-02 14:55:00  0.000000   0.0  0.0 -0.002002  0.000597 -0.006065
# 2013-01-02 15:00:00  0.000000   0.0  0.0 -0.003138  0.000358  0.007445
#
#                          USCI      WEAT      YMLP       ZSL
# Date
# 2013-01-02 14:40:00  0.018385 -0.041933 -0.002254 -0.000428
# 2013-01-02 14:45:00  0.000000  0.000000  0.000000  0.001285
# 2013-01-02 14:50:00  0.002700  0.019029 -0.001520  0.003423
# 2013-01-02 14:55:00 -0.001010  0.000934  0.003209 -0.003838
# 2013-01-02 15:00:00  0.001347 -0.000933 -0.002235 -0.005137
#
# [5 rows x 105 columns]

# %%
print('Total number of possible pairs: ', len(df_returns.columns)*(len(df_returns.columns)-1)/2)
# Out:
# Total number of possible pairs:  5460.0

# %% [markdown]
# **Applying PCA on Returns**
#
# - Protecting from `Curse of Dimensionality` - *source: https://stats.stackexchange.com/questions/232500/how-do-i-know-my-k-means-clustering-algorithm-is-suffering-from-the-curse-of-dim*: Perform a principle components analysis (PCA) and look at how the eigenvalues drop off. It is quite common that most of the variation exists in a couple of dimensions (which typically cut across the original dimensions of your dataset)

# %% [markdown]
# To analyze how many principal components we should be using, and accounting for the fact that too many features might incur curse of dimensionality, we proceed to visualize the explanatory power of the first 20 features. We observe that most of the information is in fact contained within the first features. We choose to keep the first 5.

# %%
N_PRIN_COMPONENTS = 5
X, explained_variance = (
    series_analyser
    .apply_PCA(N_PRIN_COMPONENTS, df_returns, random_state=0)
)
print(explained_variance)
# Out:
# [2.34196784e-04 1.43615518e-04 9.93884260e-05 3.93501877e-05
#  3.02258090e-05]

# %% [markdown]
# **Clustering**

# %%
def cluster_size(counts):
    plt.figure()
    plt.barh(counts.index+1, counts.values)
    #plt.title('Cluster Member Counts')
    plt.yticks(np.arange(1, len(counts)+1, 1))
    plt.xlabel('ETFs within cluster', size=12)
    plt.ylabel('Cluster Id', size=12)

# %%
clustered_series_all, clustered_series, counts, clf = (
    series_analyser
    .apply_DBSCAN(
        0.15,
        3,
        X,
        df_returns
    )
)
# Out:
# Clusters discovered: 7
# Pairs to evaluate: 145

# %%
# optics
clustered_series_all, clustered_series, counts, clf = (
    series_analyser
    .apply_OPTICS(X, df_returns, min_samples=3,
    #max_eps=5, 
    cluster_method='xi')
)
# Out:
# OPTICS(max_eps=2, metric='euclidean', min_samples=3)
# Clusters discovered: 13
# Pairs to evaluate: 160

# %%
cluster_size(counts)

# %% [markdown]
# The epsilon parameter strongly dependens on the data. Because of the that, it is not obvious wether DBSCAN is the best algo.

# %%
print(counts)
print('Average cluster size: ', np.mean(counts))
# Out:
# 2     10
# 1     10
# 6      6
# 5      6
# 0      5
# 12     4
# 7      4
# 4      3
# 11     3
# 10     3
# 9      3
# 8      3
# 3      3
# dtype: int64
# Average cluster size:  4.846153846153846

# %% [markdown]
# **Fundamental analysis for clusters**

# %%
etfs, etfs_unique, tickers = (
    data_processor
    .read_ticker_excel(path=data_path / 'etfs/commodity_ETFs_long_updated.xlsx')
)

# %%
for label_n in range(len(counts)):
    elements_cluster_n = list(clustered_series[clustered_series == label_n].index)
    etfs_cluster_n = etfs_unique[etfs_unique['Ticker'].isin(elements_cluster_n)]
    print('\nCluster {}:\n{}'.format(label_n, etfs_cluster_n[['Ticker', 'Segment']]))
# Out:
# Cluster 0:
#    Ticker                                      Segment
# 96    DBS          Commodities: Precious Metals Silver
# 62    DGP  Leveraged Commodities: Precious Metals Gold
# 40   SIVR          Commodities: Precious Metals Silver
# 24    SLV          Commodities: Precious Metals Silver
# 64    UGL  Leveraged Commodities: Precious Metals Gold
#
# Cluster 1:
#     Ticker                                 Segment
# 55     DBP            Commodities: Precious Metals
# 59     DGL       Commodities: Precious Metals Gold
# 22     GLD       Commodities: Precious Metals Gold
# 39    GLTR            Commodities: Precious Metals
# 23     IAU       Commodities: Precious Metals Gold
# 44    PALL  Commodities: Precious Metals Palladium
# 32    PPLT   Commodities: Precious Metals Platinum
# 29    SGOL       Commodities: Precious Metals Gold
# 361   SILJ            Equity: Global Silver Miners
# 360   SLVP            Equity: Global Silver Miners
#
# Cluster 2:
#    Ticker                            Segment
# 69    BCM          Commodities: Broad Market
# 2    CORN      Commodities: Agriculture Corn
# 0     DBA           Commodities: Agriculture
# 77   DJCI          Commodities: Broad Market
# 53    GCC          Commodities: Broad Market
# 6     NIB     Commodities: Agriculture Cocoa
# 18    RJA           Commodities: Agriculture
# 5    SOYB  Commodities: Agriculture Soybeans
# 36   USCI          Commodities: Broad Market
# 3    WEAT     Commodities: Agriculture Wheat
#
# Cluster 3:
#     Ticker                         Segment
# 8     CANE  Commodities: Agriculture Sugar
# 209   MLPY               Equity: U.S. MLPs
# 277    NLR   Equity: Global Nuclear Energy
#
# Cluster 4:
#     Ticker                         Segment
# 375    CGW            Equity: Global Water
# 376    FIW            Equity: Global Water
# 262    LIT  Equity: Global Metals & Mining
#
# Cluster 5:
#     Ticker                         Segment
# 146   EMLP               Equity: U.S. MLPs
# 174    KOL             Equity: Global Coal
# 264   PICK  Equity: Global Metals & Mining
# 377    PIO            Equity: Global Water
# 276    URA   Equity: Global Nuclear Energy
# 180   YMLP               Equity: U.S. MLPs
#
# Cluster 6:
#     Ticker                                          Segment
# 145    AMJ                                Equity: U.S. MLPs
# 143   AMLP                                Equity: U.S. MLPs
# 149    IXC                            Equity: Global Energy
# 148   MLPI                                Equity: U.S. MLPs
# 182    PXE  Equity: U.S. Oil & Gas Exploration & Production
# 175    PXI                              Equity: U.S. Energy
#
# Cluster 7:
#     Ticker                                      Segment
# 189   FRAK                     Equity: Global Oil & Gas
# 186   PSCE                          Equity: U.S. Energy
# 195    PXJ  Equity: U.S. Oil & Gas Equipment & Services
# 163    RYE                          Equity: U.S. Energy
#
# Cluster 8:
#     Ticker              Segment
# 153    IYE  Equity: U.S. Energy
# 144    VDE  Equity: U.S. Energy
# 142    XLE  Equity: U.S. Energy
#
# Cluster 9:
#     Ticker                                          Segment
# 164    FXN                              Equity: U.S. Energy
# 159    IEO  Equity: U.S. Oil & Gas Exploration & Production
# 165    IEZ      Equity: U.S. Oil & Gas Equipment & Services
#
# Cluster 10:
#     Ticker                    Segment
# 30     DJP  Commodities: Broad Market
# 75     GSP  Commodities: Broad Market
# 134    RJI  Commodities: Broad Market
#
# Cluster 11:
#    Ticker                    Segment
# 26    DBC  Commodities: Broad Market
# 61    DBE        Commodities: Energy
# 28    GSG  Commodities: Broad Market
#
# Cluster 12:
#    Ticker                        Segment
# 58    BNO  Commodities: Energy Crude Oil
# 41    DBO  Commodities: Energy Crude Oil
# 72    UGA   Commodities: Energy Gasoline
# 66    USL  Commodities: Energy Crude Oil

# %% [markdown]
# **Visualizing with t-sne**

# %%
def plot_TSNE(X, clf, clustered_series_all):
    """
    This function makes use of t-sne to visualize clusters in 2d.
    """
    
    X_tsne = TSNE(learning_rate=1000, perplexity=25, random_state=1337).fit_transform(X)
    
    # visualization
    fig = plt.figure(1, facecolor='white', figsize=(15,15), frameon=True, edgecolor='black')
    plt.clf()
    
    # axis in the middle
    ax = fig.add_subplot(1, 1, 1, alpha=0.9)
    # Move left y-axis and bottim x-axis to centre, passing through (0,0)
    ax.spines['left'].set_position('center')
    ax.spines['left'].set_alpha(0.3)
    ax.spines['bottom'].set_position('center')
    ax.spines['bottom'].set_alpha(0.3)
    # Eliminate upper and right axes
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    # Show ticks in the left and lower axes only
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    ax.tick_params(which='major', labelsize=18)
    #plt.axis('off')

    # etfs in cluster
    labels = clf.labels_
    x = X_tsne[(labels!=-1), 0]
    y = X_tsne[(labels!=-1), 1]
    tickers = list(clustered_series_all[clustered_series_all != -1].index)
    plt.scatter(
        x,
        y,
        s=300,
        alpha=0.75,
        c=labels[labels!=-1],
        cmap=cm.Paired
    )
    for i, ticker in enumerate(tickers):
        plt.annotate(ticker, (x[i]-20, y[i]+12), size=15)

    # remaining etfs, not clustered
    x = X_tsne[(clustered_series_all==-1).values, 0]
    y = X_tsne[(clustered_series_all==-1).values, 1]
    tickers = list(clustered_series_all[clustered_series_all == -1].index)

    # WARNING: elimintate outliers
    #outliers = ['DTO','SCO']
    outliers = ['DZZ', 'XME']
    to_remove_x = [x[clustered_series_all[clustered_series_all==-1].index.get_loc(outliers[0])],
                   x[clustered_series_all[clustered_series_all==-1].index.get_loc(outliers[1])]]
    to_remove_y = [y[clustered_series_all[clustered_series_all==-1].index.get_loc(outliers[0])],
                   y[clustered_series_all[clustered_series_all==-1].index.get_loc(outliers[1])]]
    x = np.array([i for i in x if i not in to_remove_x])
    y= np.array([i for i in y if i not in to_remove_y])

    plt.scatter(
        x,
        y,
        s=150,
        alpha=0.20,
        c='black'
    )
    #for i, ticker in enumerate(tickers):
    #    plt.annotate(ticker, (x[i]+20, y[i]+20))#, arrowprops={'arrowstyle':'simple'})
        
    #plt.title('OPTICS clusters visualized with t-SNE', size=16);
    plt.xlabel('t-SNE Dim. 1', position=(0.92,0), size=20)
    plt.ylabel('t-SNE Dim. 2', position=(0,0.92), size=20)
    ax.set_xticks(range(-300, 301, 600))
    ax.set_yticks(range(-300, 301, 600))
    #plt.savefig('DBSCAN_2014_2018_eps0_15.png', bbox_inches='tight', pad_inches=0.01)
    plt.savefig('OPTICS_2013_2017.png', bbox_inches='tight', pad_inches=0.1)
    plt.show()
    # include connections - see quontopian

# %%
plot_TSNE(X,clf, clustered_series_all)
# Out:
# C:\Users\gabri\anaconda3\envs\algoritmica\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %% [markdown]
# What can we conclude??
# - First of all, the securities in each cluster are indeed from segments tham seem to be fundamentally related.
# - Moreover, we see that some filtering is being performed, and the clustering goes further than a simple groupby segment would.
#
# Let's proceed to plot the identified time series.

# %%
plt.rcParams.update({'font.size': 12})

# %%
for clust in range(len(counts)):
    symbols = list(clustered_series[clustered_series==clust].index)
    means = np.log(df_prices_train[symbols].mean())
    series = np.log(df_prices_train[symbols]).sub(means)
    series.plot(figsize=(10,5))#title='ETFs Time Series for Cluster %d' % (clust+1))
    #plt.ylabel('Normalized log prices', size=12)
    #plt.xlabel('Date', size=12)
    plt.savefig('cluster_{}.png'.format(str(clust+1)), bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# We now investigate whether it is possible to find cointegrated pairs within the clusters

# %%
pairs_unsupervised, unique_tickers = (
    series_analyser
    .get_candidate_pairs(
        clustered_series=clustered_series,
        pricing_df_train=df_prices_train,
        pricing_df_test=df_prices_test,
        min_half_life=min_half_life,
        max_half_life=max_half_life,
        min_zero_crosings=12,
        p_value_threshold=0.10,
        hurst_threshold=0.5,
        subsample=subsample
    )
)
# Out:
# Cluster 1/13
# Cluster 2/13
# Cluster 3/13
# Cluster 4/13
# Cluster 5/13
# Cluster 6/13
# Cluster 7/13
# Cluster 8/13
# Cluster 9/13
# Cluster 10/13
# Cluster 11/13
# Cluster 12/13
# Cluster 13/13
# Found 52 pairs
# The pairs contain 50 unique tickers
# Pairs Selection failed stage:  {'cointegration': 94, 'hurst_exponent': 3, 'half_life': 11, 'None': 52}

# %%
with open(data_path / ('etfs/pickle/2015-2019/pairs_unsupervised_learning_optical_' + file_extension + '_p005_seed0.pickle'), 'wb') as f:
    pickle.dump(pairs_unsupervised, f)

# %%
pairs_unsupervised[0][2]['spread']
# Out:
# Date
# 2013-01-02 14:35:00   -0.356696
# 2013-01-02 14:40:00   -0.355715
# 2013-01-02 14:45:00   -0.247645
# 2013-01-02 14:50:00   -0.247645
# 2013-01-02 14:55:00   -0.059581
#                          ...
# 2015-12-30 20:40:00   -3.597192
# 2015-12-30 20:45:00   -3.597192
# 2015-12-30 20:50:00   -3.597192
# 2015-12-30 20:55:00   -3.597192
# 2015-12-30 21:00:00   -3.606192
# Length: 58602, dtype: float64

# %%
for pair in pairs_unsupervised:
    pair[2]['spread'].plot()

# %%
for pair in pairs_unsupervised:
    print(pair[2]['zero_cross'])
# Out:
# 335
# 391
# 367
# 1199
# 1475
# 954
# 113
# 184
# 1035
# 850
# 77
# 228
# 900
# 190
# 1050
# 252
# 111
# 276
# 716
# 396
# 151
# 168
# 256
# 478
# 1124
# 527
# 648
# 457
# 295
# 483
# 297
# 264
# 96
# 75
# 371
# 316
# 618
# 190
# 592
# 1378
# 702
# 5979
# 822
# 855
# 821
# 479
# 1071
# 469
# 540
# 1487
# 564
# 552

# %%
count_different_category = 0
for pair in pairs_unsupervised:
    print('------------------------------------------------')
    print('Leg 1: {}. Segment: {}. Category: {}'.format(pair[0], df_category.loc[pair[0]]['Segment'] ,
                                                        df_category.loc[pair[0]]['Category']))
    print('Leg 2: {}. Segment: {}. Category: {}'.format(pair[1], df_category.loc[pair[1]]['Segment'],
                                                        df_category.loc[pair[1]]['Category']))
    if df_category.loc[pair[0]]['Category'] != df_category.loc[pair[1]]['Category']:
        count_different_category += 1
print('There are {} pairs from different categories'.format(count_different_category))
# Out:
# ------------------------------------------------
# Leg 1: DBS. Segment: Commodities: Precious Metals Silver. Category: Precious Metals
# Leg 2: DGP. Segment: Leveraged Commodities: Precious Metals Gold. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DGP. Segment: Leveraged Commodities: Precious Metals Gold. Category: Precious Metals
# Leg 2: SLV. Segment: Commodities: Precious Metals Silver. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DGP. Segment: Leveraged Commodities: Precious Metals Gold. Category: Precious Metals
# Leg 2: SIVR. Segment: Commodities: Precious Metals Silver. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DBP. Segment: Commodities: Precious Metals. Category: Precious Metals
# Leg 2: GLD. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DBP. Segment: Commodities: Precious Metals. Category: Precious Metals
# Leg 2: IAU. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DBP. Segment: Commodities: Precious Metals. Category: Precious Metals
# Leg 2: GLTR. Segment: Commodities: Precious Metals. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DBP. Segment: Commodities: Precious Metals. Category: Precious Metals
# Leg 2: PALL. Segment: Commodities: Precious Metals Palladium. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DBP. Segment: Commodities: Precious Metals. Category: Precious Metals
# Leg 2: PPLT. Segment: Commodities: Precious Metals Platinum. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DBP. Segment: Commodities: Precious Metals. Category: Precious Metals
# Leg 2: SGOL. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DGL. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# Leg 2: GLTR. Segment: Commodities: Precious Metals. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DGL. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# Leg 2: PALL. Segment: Commodities: Precious Metals Palladium. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DGL. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# Leg 2: PPLT. Segment: Commodities: Precious Metals Platinum. Category: Precious Metals
# ------------------------------------------------
# Leg 1: GLD. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# Leg 2: GLTR. Segment: Commodities: Precious Metals. Category: Precious Metals
# ------------------------------------------------
# Leg 1: GLD. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# Leg 2: PPLT. Segment: Commodities: Precious Metals Platinum. Category: Precious Metals
# ------------------------------------------------
# Leg 1: IAU. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# Leg 2: GLTR. Segment: Commodities: Precious Metals. Category: Precious Metals
# ------------------------------------------------
# Leg 1: IAU. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# Leg 2: PPLT. Segment: Commodities: Precious Metals Platinum. Category: Precious Metals
# ------------------------------------------------
# Leg 1: GLTR. Segment: Commodities: Precious Metals. Category: Precious Metals
# Leg 2: PALL. Segment: Commodities: Precious Metals Palladium. Category: Precious Metals
# ------------------------------------------------
# Leg 1: GLTR. Segment: Commodities: Precious Metals. Category: Precious Metals
# Leg 2: PPLT. Segment: Commodities: Precious Metals Platinum. Category: Precious Metals
# ------------------------------------------------
# Leg 1: GLTR. Segment: Commodities: Precious Metals. Category: Precious Metals
# Leg 2: SGOL. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# ------------------------------------------------
# Leg 1: GLTR. Segment: Commodities: Precious Metals. Category: Precious Metals
# Leg 2: SILJ. Segment: Equity: Global Silver Miners. Category: Precious Metals
# ------------------------------------------------
# Leg 1: PALL. Segment: Commodities: Precious Metals Palladium. Category: Precious Metals
# Leg 2: SILJ. Segment: Equity: Global Silver Miners. Category: Precious Metals
# ------------------------------------------------
# Leg 1: PPLT. Segment: Commodities: Precious Metals Platinum. Category: Precious Metals
# Leg 2: SGOL. Segment: Commodities: Precious Metals Gold. Category: Precious Metals
# ------------------------------------------------
# Leg 1: PPLT. Segment: Commodities: Precious Metals Platinum. Category: Precious Metals
# Leg 2: SILJ. Segment: Equity: Global Silver Miners. Category: Precious Metals
# ------------------------------------------------
# Leg 1: DBA. Segment: Commodities: Agriculture. Category: Agriculture
# Leg 2: USCI. Segment: Commodities: Broad Market. Category: Broad Market
# ------------------------------------------------
# Leg 1: GCC. Segment: Commodities: Broad Market. Category: Broad Market
# Leg 2: DJCI. Segment: Commodities: Broad Market. Category: Broad Market
# ------------------------------------------------
# Leg 1: GCC. Segment: Commodities: Broad Market. Category: Broad Market
# Leg 2: SOYB. Segment: Commodities: Agriculture Soybeans. Category: Agriculture
# ------------------------------------------------
# Leg 1: RJA. Segment: Commodities: Agriculture. Category: Agriculture
# Leg 2: SOYB. Segment: Commodities: Agriculture Soybeans. Category: Agriculture
# ------------------------------------------------
# Leg 1: BCM. Segment: Commodities: Broad Market. Category: Broad Market
# Leg 2: DJCI. Segment: Commodities: Broad Market. Category: Broad Market
# ------------------------------------------------
# Leg 1: BCM. Segment: Commodities: Broad Market. Category: Broad Market
# Leg 2: SOYB. Segment: Commodities: Agriculture Soybeans. Category: Agriculture
# ------------------------------------------------
# Leg 1: CORN. Segment: Commodities: Agriculture Corn. Category: Agriculture
# Leg 2: WEAT. Segment: Commodities: Agriculture Wheat. Category: Agriculture
# ------------------------------------------------
# Leg 1: DJCI. Segment: Commodities: Broad Market. Category: Broad Market
# Leg 2: SOYB. Segment: Commodities: Agriculture Soybeans. Category: Agriculture
# ------------------------------------------------
# Leg 1: SOYB. Segment: Commodities: Agriculture Soybeans. Category: Agriculture
# Leg 2: WEAT. Segment: Commodities: Agriculture Wheat. Category: Agriculture
# ------------------------------------------------
# Leg 1: CANE. Segment: Commodities: Agriculture Sugar. Category: Agriculture
# Leg 2: MLPY. Segment: Equity: U.S. MLPs. Category: Energy
# ------------------------------------------------
# Leg 1: FIW. Segment: Equity: Global Water. Category: Agriculture
# Leg 2: LIT. Segment: Equity: Global Metals & Mining. Category: Industrial Metals
# ------------------------------------------------
# Leg 1: KOL. Segment: Equity: Global Coal. Category: Energy
# Leg 2: URA. Segment: Equity: Global Nuclear Energy. Category: Energy
# ------------------------------------------------
# Leg 1: KOL. Segment: Equity: Global Coal. Category: Energy
# Leg 2: YMLP. Segment: Equity: U.S. MLPs. Category: Energy
# ------------------------------------------------
# Leg 1: PICK. Segment: Equity: Global Metals & Mining. Category: Industrial Metals
# Leg 2: YMLP. Segment: Equity: U.S. MLPs. Category: Energy
# ------------------------------------------------
# Leg 1: URA. Segment: Equity: Global Nuclear Energy. Category: Energy
# Leg 2: YMLP. Segment: Equity: U.S. MLPs. Category: Energy
# ------------------------------------------------
# Leg 1: IXC. Segment: Equity: Global Energy. Category: Energy
# Leg 2: PXE. Segment: Equity: U.S. Oil & Gas Exploration & Production. Category: Energy
# ------------------------------------------------
# Leg 1: IXC. Segment: Equity: Global Energy. Category: Energy
# Leg 2: PXI. Segment: Equity: U.S. Energy. Category: Energy
# ------------------------------------------------
# Leg 1: PXE. Segment: Equity: U.S. Oil & Gas Exploration & Production. Category: Energy
# Leg 2: PXI. Segment: Equity: U.S. Energy. Category: Energy
# ------------------------------------------------
# Leg 1: AMLP. Segment: Equity: U.S. MLPs. Category: Energy
# Leg 2: MLPI. Segment: Equity: U.S. MLPs. Category: Energy
# ------------------------------------------------
# Leg 1: RYE. Segment: Equity: U.S. Energy. Category: Energy
# Leg 2: FRAK. Segment: Equity: Global Oil & Gas. Category: Energy
# ------------------------------------------------
# Leg 1: IYE. Segment: Equity: U.S. Energy. Category: Energy
# Leg 2: XLE. Segment: Equity: U.S. Energy. Category: Energy
# ------------------------------------------------
# Leg 1: VDE. Segment: Equity: U.S. Energy. Category: Energy
# Leg 2: XLE. Segment: Equity: U.S. Energy. Category: Energy
# ------------------------------------------------
# Leg 1: FXN. Segment: Equity: U.S. Energy. Category: Energy
# Leg 2: IEO. Segment: Equity: U.S. Oil & Gas Exploration & Production. Category: Energy
# ------------------------------------------------
# Leg 1: DJP. Segment: Commodities: Broad Market. Category: Broad Market
# Leg 2: RJI. Segment: Commodities: Broad Market. Category: Broad Market
# ------------------------------------------------
# Leg 1: DBC. Segment: Commodities: Broad Market. Category: Broad Market
# Leg 2: DBE. Segment: Commodities: Energy. Category: Energy
# ------------------------------------------------
# Leg 1: DBC. Segment: Commodities: Broad Market. Category: Broad Market
# Leg 2: GSG. Segment: Commodities: Broad Market. Category: Broad Market
# ------------------------------------------------
# Leg 1: DBE. Segment: Commodities: Energy. Category: Energy
# Leg 2: GSG. Segment: Commodities: Broad Market. Category: Broad Market
# ------------------------------------------------
# Leg 1: DBO. Segment: Commodities: Energy Crude Oil. Category: Energy
# Leg 2: UGA. Segment: Commodities: Energy Gasoline. Category: Energy
# ------------------------------------------------
# Leg 1: UGA. Segment: Commodities: Energy Gasoline. Category: Energy
# Leg 2: BNO. Segment: Commodities: Energy Crude Oil. Category: Energy
# There are 9 pairs from different categories
